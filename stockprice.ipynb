# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame


start = datetime.datetime(2010, 1, 1)
end = datetime.datetime.now()

df = web.DataReader("AAPL", 'yahoo', start, end)
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-05-16  147.520004  144.179993  145.550003  145.539993   86643800.0
# 2022-05-17  149.770004  146.679993  148.860001  149.240005   78336300.0
# 2022-05-18  147.360001  139.899994  146.850006  140.820007  109742900.0
# 2022-05-19  141.660004  136.600006  139.880005  137.350006  136095600.0
# 2022-05-20  140.699997  132.610001  139.089996  137.589996  137194600.0
#
#              Adj Close
# Date
# 2022-05-16  145.539993
# 2022-05-17  149.240005
# 2022-05-18  140.820007
# 2022-05-19  137.350006
# 2022-05-20  137.589996

# %%
close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()
mavg.tail(10)
# Out:
# Date
# 2022-05-09    167.923659
# 2022-05-10    167.680667
# 2022-05-11    167.427783
# 2022-05-12    167.146669
# 2022-05-13    166.924916
# 2022-05-16    166.655152
# 2022-05-17    166.395960
# 2022-05-18    166.046186
# 2022-05-19    165.621323
# 2022-05-20    165.209232
# Name: Adj Close, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(20, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

close_px.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()

# %%
plt.plot(close_px, label='AAPL')
plt.plot(mavg, label='mavg')
plt.legend()
